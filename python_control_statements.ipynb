# %%
'''1. Check Even or Odd
Question: Determine whether a number is even or odd. Explanation: A number is even if it is divisible by 2. 
Otherwise, it’s odd. - Input: Number = 6 - Output: Even number
'''
n = int(input())
print("Even number" if n%2==0 else "Odd number")

# %%
l = [10, 20, 30, 40]
new_l = lambda l: [i**2 for i in l]
print(new_l(l))
# Out:
# [100, 400, 900, 1600]

# %%
'''2. Divisible by 5 but Not by 10
Question: Check if a number is divisible by 5 but not by 10.
Explanation: Use modulo (%) to check if the number % 5 == 0 and number % 10 != 0. - Input: Number = 25 - Output: Satisfy
'''
n = int(input())
print("satisfy" if n%5==0 and n%10!=0 else "not satisfy")

# %%
'''3. Biggest Among Two Numbers
Question: Find the biggest number among two. 
Explanation: Use comparison operators (>) to check which number is greater. - Input: A = 4, B = 7 - Output: Biggest is: 7
'''
A = int(input())
B = int(input())
if A>B:
    print(f"Biggest is: {A}")
elif B>A:
    print(f"Biggest is: {B}")
else:
    print("Both are equal")

# %%
'''4. Smallest Among Two Numbers
Question: Find the smallest number among two. 
Explanation: Use comparison operators (<) to find the smaller value. - Input: A = 4, B = 7 - Output: Smallest is: 4
'''
A = int(input())
B = int(input())
if A<B:
    print(f"Smallest is: {A}")
elif B<A:
    print(f"Smallest is: {B}")
else:
    print("Both are equal")

# %%
'''5. Divisible by 2, 3, and 6
Question: Check if a number is divisible by 2, 3, and 6. 
Explanation: If a number is divisible by both 2 and 3, it is also divisible by 6. - Input: Number = 18 - Output: Satisfy
'''
n = int(input())
print("satisfy" if n%2==0 and n%3==0 else "not satisfy")

# %%
'''6. Voting Eligibility
Question: Check if a person is eligible to vote (age >= 18). 
Explanation: A person is eligible to vote if their age is 18 or above. - Input: Age = 19 - Output: Eligible to vote
'''
age = int(input())
print("Eligible to vote" if age>=18 else "Not eligible to vote")

# %%
'''7. Student Pass/Fail Based on All Subjects >= 35
Question: Check if a student passed all subjects (maths, physics, chemistry). 
Explanation: Student passes only if marks in all subjects are 35 or more. - 
Input: Maths = 40, Physics = 36, Chemistry = 30 - Output: Fail
'''
maths_marks = int(input())
physics_marks = int(input())
chemistry_marks = int(input())
if maths_marks >= 35 and physics_marks >= 35 and chemistry_marks >= 35:
    print("Pass")
else:
    print("Fail")

# %%
'''8. Student Pass if Passed Any One Subject (>= 35)
Question: Check if the student passed at least one subject. 
Explanation: Use logical OR to check if any one subject has marks >= 35. - 
Input: Maths = 20, Physics = 38, Chemistry = 25 - Output: Pass
'''
maths_marks = int(input())
physics_marks = int(input())
chemistry_marks = int(input())
if maths_marks >= 35 or physics_marks >= 35 or chemistry_marks >= 35:
    print("Pass")
else:
    print("Fail")

# %%
'''9. Student Pass if Passed Any Two Subjects
Question: Check if the student passed any two out of three subjects. 
Explanation: Use a counter or logical conditions to verify two subjects >= 35. - 
Input: Maths = 40, Physics = 20, Chemistry = 36 - Output: Pass
'''
maths_marks = int(input())
physics_marks = int(input())
chemistry_marks = int(input())

passed_subjects = (maths_marks >= 35) + (physics_marks >= 35) + (chemistry_marks >= 35)
print(passed_subjects)
if passed_subjects >= 2:
    print("Pass")
else:
    print("Fail")

# %%
'''10. Biggest Among Three Numbers
Question: Find the biggest number among three. 
Explanation: Compare each pair of numbers using if-else conditions. - Input: A = 7, B = 4, C = 9 - Output: Biggest is: 9
'''
A = int(input())
B = int(input())
C = int(input())
biggest = 0
if A>B and A>C:
    Biggest = A
elif B>A and B>C:
    Biggest = B
else:
    Biggest = C
print(f"Biggest is: {Biggest}")

# %%
'''11. Smallest Among Three Numbers
Question: Find the smallest number among three. 
Explanation: Use comparison logic to determine the minimum value. - Input: A = 7, B = 4, C = 9 - Output: Smallest is: 4
'''
A = int(input())
B = int(input())
C = int(input())
biggest = 0
if A<B and A<C:
    Smallest = A
elif B<A and B<C:
    Smallest = B
else:
    Smallest = C
print(f"Smallest is: {Smallest}")

# %%
'''
12. Perfect Square or Not
Question: Check if a number is a perfect square. 
Explanation: A number is a perfect square if the square of its square root equals the number. - 
Input: Number = 49 - Output: Perfect square
'''
import math
n = int(input())
result = int(math.sqrt(n))
if result*result == n:
    print(f"{n} is a perfect square")
else:
    print(f"{n} is not a perfect square")

# %%
'''13. Cars Required for Members (Max 5 per car)
Question: Calculate how many cars are needed for a given number of people. 
Explanation: Divide total people by 5 and round up using ceiling logic. - Input: Members = 17 - Output: Cars needed = 4
'''
import math
members = int(input())
cars_required = math.ceil(members/5)
print(f"Cars needed = {cars_required}")

# %%
'''14. Second Biggest Among Three Numbers
Question: Find the second largest number among three inputs. 
Explanation: Use sorting or nested conditions to find the second largest value. - 
Input: A = 10, B = 25, C = 18 - Output: Second biggest: 18
'''
A = int(input())
B = int(input())
C = int(input())
second_highest = 0
if A>B and A<C:
    second_highest = A
elif B>A and B<C:
    second_highest = B
else:
    second_highest = C
print(f"Seccond biggest: {second_highest}")

# %%
'''15. Leap Year or Not
Question: Check if a given year is a leap year. 
Explanation: A year is a leap year if it is divisible by 4, and (not divisible by 100 unless divisible by 400). - 
Input: Year = 2024 - Output: Leap year
'''
year = int(input())
if (year%4 == 0 and year%100!=0) or year%400==0:
    print(f"{year} is a Leap year")
else:
    print(f"{year} is not a Leap year")
